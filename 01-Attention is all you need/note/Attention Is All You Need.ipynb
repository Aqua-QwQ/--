# %% [markdown]
# # 《Attention Is All You Need》阅读与资料整理笔记
#
# > 用法：将此前查找的资料、页码和链接回填到每个 `[待补充]` 位置；每条关键结论都保留可追溯的证据。
#
# **原文文件：** `../PDF/01_attention_is_all_you_need.pdf`
# **论文：** Vaswani et al., NeurIPS 2017
# **阅读日期：** [待补充]

# %% [markdown]
# ## TL;DR
#
# - **核心主张：** [待补充]
# - **方法一句话：** 以多头自注意力和前馈网络构成编码器—解码器，使用位置编码补充序列位置信息。
# - **主要结果：** [待补充：数据集、指标、数值、基线]
# - **我的判断：** [待补充]

# %% [markdown]
# ## 1. 研究问题与背景
#
# ### 作者要解决什么问题？
# [待补充]
#
# ### 为什么已有方法不够好？
#
# | 已有方法 | 局限 | 本文回应 | 证据来源 |
# | --- | --- | --- | --- |
# | RNN / LSTM | [待补充] | [待补充] | [页码/链接] |
# | CNN | [待补充] | [待补充] | [页码/链接] |

# %% [markdown]
# ## 2. 方法拆解
#
# ### 总体架构
# `输入嵌入 + 位置编码 → 编码器层 × N → 解码器层 × N → 线性层 + Softmax`
#
# **数据流解释：** [待补充]
#
# ### 缩放点积注意力
#
# $$\operatorname{Attention}(Q,K,V)=\operatorname{softmax}\left(\frac{QK^T}{\sqrt{d_k}}\right)V$$
#
# - Q、K、V：[待补充]
# - 缩放原因：[待补充]
# - 直觉解释：[待补充]
#
# ### 多头注意力与位置编码
# - 多头的作用：[待补充]
# - 位置编码为何必要：[待补充]
# - 与可学习位置编码的比较：[待补充]

# %%
# 可选：记录核心超参数，便于与后续资料或复现实验比较
model_config = {
    'num_layers': '[待补充]',
    'model_dimension': '[待补充]',
    'num_heads': '[待补充]',
    'feed_forward_dimension': '[待补充]',
    'dropout': '[待补充]',
}
model_config

# %% [markdown]
# ## 3. 训练、实验与证据
#
# | 项目 | 论文设置 / 结果 | 我的理解 | 来源 |
# | --- | --- | --- | --- |
# | 数据集 | [待补充] | [待补充] | [页码/链接] |
# | 评价指标 | [待补充] | [待补充] | [页码/链接] |
# | 优化器与学习率 | [待补充] | [待补充] | [页码/链接] |
# | 性能结果 | [待补充] | [待补充] | [页码/链接] |
# | 训练成本 | [待补充] | [待补充] | [页码/链接] |
#
# ### 结果判断
# - 哪一项结果最能支持论文主张？[待补充]
# - 对比是否公平、是否足够？[待补充]
# - 还需要什么证据？[待补充]

# %%
# 可选：把延伸资料做成可核查的卡片；执行此单元无需额外依赖
sources = [
    {
        'title': '[资料标题]',
        'type': '论文 / 官方文档 / 教程 / 博客',
        'url_or_path': '[链接或文件]',
        'key_claim': '[可核实的关键结论]',
        'evidence_location': '[页码、章节或时间戳]',
        'reliability_note': '[可信度与局限]',
    }
]
sources

# %% [markdown]
# ## 4. 批判性思考与迁移
#
# - **成立的前提：** [待补充]
# - **局限性：** [待补充，例如长序列计算复杂度、实验覆盖度]
# - **可能的替代解释：** [待补充]
# - **与后续研究的关系：** [待补充]
# - **与我的课题 / 写作的连接：** [待补充]
# - **仍待验证的问题：** [待补充]

# %% [markdown]
# ## 5. 下一步行动
#
# - [ ] 回填所有结果数值及其页码。
# - [ ] 为关键结论补足至少一条可追溯来源。
# - [ ] 选择 2-3 条可用于正文的证据。
# - [ ] 记录最小复现实验或伪代码思路。
